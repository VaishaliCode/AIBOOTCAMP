# %%
# !pip install wordcloud

# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ICEEM\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ICEEM\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = """
Yo! I gotta say, I'm absolutely obsessed with anime! It's not just a hobby, it's a way of life. From epic battles to heartwarming stories, anime has everything I need to escape and dive into new worlds. Honestly, I watch anime whenever I can—whether it's a lazy weekend or after a long day.

There's something about the characters, the art, and those intense plot twists that just keep me hooked. Every new show feels like an adventure, and I'm always ready to binge-watch the next season.

No doubt about it—anime is life!
"""
print(text)
# Out:
# Yo! I gotta say, I'm absolutely obsessed with anime! It's not just a hobby, it's a way of life. From epic battles to heartwarming stories, anime has everything I need to escape and dive into new worlds. Honestly, I watch anime whenever I can—whether it's a lazy weekend or after a long day.
#
# There's something about the characters, the art, and those intense plot twists that just keep me hooked. Every new show feels like an adventure, and I'm always ready to binge-watch the next season.
#
# No doubt about it—anime is life!

# %%
from nltk.tokenize import word_tokenize

text = """
Yo! I gotta say, I'm absolutely obsessed with anime! It's not just a hobby, it's a way of life. From epic battles to heartwarming stories, anime has everything I need to escape and dive into new worlds. Honestly, I watch anime whenever I can—whether it's a lazy weekend or after a long day.

There's something about the characters, the art, and those intense plot twists that just keep me hooked. Every new show feels like an adventure, and I'm always ready to binge-watch the next season.

No doubt about it—anime is life!
"""

words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)
# Out:
# ['yo', '!', 'i', 'got', 'ta', 'say', ',', 'i', "'m", 'absolutely', 'obsessed', 'with', 'anime', '!', 'it', "'s", 'not', 'just', 'a', 'hobby', ',', 'it', "'s", 'a', 'way', 'of', 'life', '.', 'from', 'epic', 'battles', 'to', 'heartwarming', 'stories', ',', 'anime', 'has', 'everything', 'i', 'need', 'to', 'escape', 'and', 'dive', 'into', 'new', 'worlds', '.', 'honestly', ',', 'i', 'watch', 'anime', 'whenever', 'i', 'can—whether', 'it', "'s", 'a', 'lazy', 'weekend', 'or', 'after', 'a', 'long', 'day', '.', 'there', "'s", 'something', 'about', 'the', 'characters', ',', 'the', 'art', ',', 'and', 'those', 'intense', 'plot', 'twists', 'that', 'just', 'keep', 'me', 'hooked', '.', 'every', 'new', 'show', 'feels', 'like', 'an', 'adventure', ',', 'and', 'i', "'m", 'always', 'ready', 'to', 'binge-watch', 'the', 'next', 'season', '.', 'no', 'doubt', 'about', 'it—anime', 'is', 'life', '!']

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)
# Out:
# ['yo', 'got', 'ta', 'say', 'absolutely', 'obsessed', 'anime', 'hobby', 'way', 'life', 'epic', 'battles', 'heartwarming', 'stories', 'anime', 'everything', 'need', 'escape', 'dive', 'new', 'worlds', 'honestly', 'watch', 'anime', 'whenever', 'lazy', 'weekend', 'long', 'day', 'something', 'characters', 'art', 'intense', 'plot', 'twists', 'keep', 'hooked', 'every', 'new', 'show', 'feels', 'like', 'adventure', 'always', 'ready', 'next', 'season', 'doubt', 'life']

# %%
# Frequency distribution of words
word_freq = Counter(filtered_words)
print(word_freq)
# Out:
# Counter({'anime': 3, 'life': 2, 'new': 2, 'yo': 1, 'got': 1, 'ta': 1, 'say': 1, 'absolutely': 1, 'obsessed': 1, 'hobby': 1, 'way': 1, 'epic': 1, 'battles': 1, 'heartwarming': 1, 'stories': 1, 'everything': 1, 'need': 1, 'escape': 1, 'dive': 1, 'worlds': 1, 'honestly': 1, 'watch': 1, 'whenever': 1, 'lazy': 1, 'weekend': 1, 'long': 1, 'day': 1, 'something': 1, 'characters': 1, 'art': 1, 'intense': 1, 'plot': 1, 'twists': 1, 'keep': 1, 'hooked': 1, 'every': 1, 'show': 1, 'feels': 1, 'like': 1, 'adventure': 1, 'always': 1, 'ready': 1, 'next': 1, 'season': 1, 'doubt': 1})

# %%
# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
# Plotting the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
